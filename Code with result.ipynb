# %% [markdown]
# <a href="https://colab.research.google.com/github/giovannicassini/anomalysegmentation/blob/main/Code%20with%20result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -r ./*
# %cd /content
# !git clone https://github.com/mcordts/cityscapesScripts
# !git clone https://github.com/giovannicassini/anomalysegmentation

# !pip install ood_metrics
# !pip install erfnet
# !pip install numpy
# !pip install matplotlib
# !pip install Pillow
# !pip install torchvision
# !pip install visdom
# !pip install pyquaternion
# !pip install cityscapesscripts
# !pip install wget
# Out:
# /content
# Cloning into 'cityscapesScripts'...
# remote: Enumerating objects: 640, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 640 (delta 179), reused 163 (delta 156), pack-reused 427
# Receiving objects: 100% (640/640), 793.19 KiB | 3.02 MiB/s, done.
# Resolving deltas: 100% (365/365), done.
# Cloning into 'anomalysegmentation'...
# remote: Enumerating objects: 3498, done.
# remote: Counting objects: 100% (675/675), done.
# remote: Compressing objects: 100% (641/641), done.
# remote: Total 3498 (delta 169), reused 492 (delta 33), pack-reused 2823
# Receiving objects: 100% (3498/3498), 1.46 GiB | 16.44 MiB/s, done.
# Resolving deltas: 100% (685/685), done.
# Updating files: 100% (3147/3147), done.
# ...
# ERROR: Could not find a version that satisfies the requirement erfnet (from versions: none)
# ERROR: No matching distribution found for erfnet
# ...

# %%
# !cp -r /content/anomalysegmentation/gtFine /content/cityscapesScripts
# !cp -r /content/anomalysegmentation/leftImg8bit /content/cityscapesScripts
# %cd /content/cityscapesScripts
# !python cityscapesscripts/preparation/createTrainIdLabelImgs.py
# Out:
# Exception in thread Thread-5 (attachment_entry):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/debugpy/server/api.py", line 237, in listen
#     sock, _ = endpoints_listener.accept()
#   File "/usr/lib/python3.10/socket.py", line 293, in accept
#     fd, addr = self._accept()
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_debugpy.py", line 52, in attachment_entry
#     debugpy.listen(_dap_port)
#   File "/usr/local/lib/python3.10/dist-packages/debugpy/public_api.py", line 31, in wrapper
#     return wrapped(*args, **kwargs)
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python eval_iou.py --datadir /content/cityscapesScripts --subset val
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/cityscapesScripts/leftImg8bit/val /content/cityscapesScripts/gtFine/val
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 0 val/frankfurt/frankfurt_000000_000294_leftImg8bit.png
# 1 val/frankfurt/frankfurt_000000_000576_leftImg8bit.png
# 2 val/frankfurt/frankfurt_000000_001016_leftImg8bit.png
# ...

# %% [markdown]
# **Max Logit**

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/1.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly.py --input '/content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/*.webp'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/19.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/20.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/7.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/6.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/27.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/21.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/14.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/2.webp
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly.py --input '/content/anomalysegmentation/Validation_Dataset/fs_static/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/15.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/25.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/26.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/7.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/8.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/24.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly.py --input '/content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/35.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/43.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/63.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/16.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/45.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/68.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/7.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/56.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/4.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/57.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/38.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/32.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/42.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/53.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/49.jpg
# ...

# %% [markdown]
# **MSP**

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/57.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/38.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/32.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/42.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/53.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/6.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/8.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/*.webp'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/19.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/20.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/7.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/6.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/27.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/21.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/14.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/2.webp
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/35.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/43.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/63.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/16.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/45.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/68.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/7.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/56.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/fs_static/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/15.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/25.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/26.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/7.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/8.jpg
# ...

# %% [markdown]
# **Max Entropy**

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_maxentropy.py --input '/content/anomalysegmentation/Validation_Dataset/fs_static/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/15.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/25.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/26.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/7.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/8.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/24.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_maxentropy.py --input '/content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/35.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/43.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/63.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/16.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/45.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/68.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/7.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/56.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/4.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_maxentropy.py --input '/content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/*.webp'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/19.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/20.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/7.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/6.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/27.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/21.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/14.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/2.webp
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_maxentropy.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/57.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/38.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/32.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/42.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/53.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/49.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_maxentropy.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/8.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/1.png
# ...

# %% [markdown]
# **MSP with temperature scaling t = 0.5**

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.5
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/57.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/38.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/32.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/42.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/53.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/6.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.5
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/8.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/*.webp'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.5
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/19.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/20.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/7.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/6.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/27.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/21.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/14.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/2.webp
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.5
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/35.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/43.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/63.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/16.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/45.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/68.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/7.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/56.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/fs_static/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.5
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/15.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/25.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/26.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/7.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/8.jpg
# ...

# %% [markdown]
# **MSP with temperature scaling: t= 0.75**

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.75
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/57.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/38.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/32.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/42.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/53.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/6.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.75
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/8.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/*.webp'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.75
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/19.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/20.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/7.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/6.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/27.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/21.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/14.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/2.webp
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.75
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/35.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/43.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/63.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/16.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/45.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/68.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/7.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/56.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/fs_static/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.75
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/15.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/25.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/26.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/7.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/8.jpg
# ...

# %% [markdown]
# **MSP with temperature scaling: t = 1.1**

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1.1
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/57.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/38.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/32.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/42.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/53.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/6.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1.1
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/8.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/*.webp'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1.1
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/19.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/20.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/7.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/6.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/27.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/21.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/14.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/2.webp
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1.1
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/35.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/43.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/63.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/16.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/45.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/68.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/7.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/56.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/fs_static/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 1.1
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/15.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/25.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/26.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/7.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/8.jpg
# ...

# %% [markdown]
# **MSP with temperature scaling: t= 0.00001 (t best)**

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.00001
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/57.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/38.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/32.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/42.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/53.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly/images/6.jpg
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.00001
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/7.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/2.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/0.png
# /content/anomalysegmentation/Validation_Dataset/RoadAnomaly21/images/8.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/*.webp'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.00001
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/19.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/20.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/7.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/6.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/27.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/21.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/14.webp
# /content/anomalysegmentation/Validation_Dataset/RoadObsticle21/images/2.webp
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/*.png'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.00001
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/35.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/43.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/63.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/16.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/45.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/68.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/7.png
# /content/anomalysegmentation/Validation_Dataset/FS_LostFound_full/images/56.png
# ...

# %%
# %cd /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# !python evalAnomaly_MSP.py --input '/content/anomalysegmentation/Validation_Dataset/fs_static/images/*.jpg'
# Out:
# /content/anomalysegmentation/AnomalySegmentation_CourseProjectBaseCode/eval
# Loading model: ../trained_models/erfnet.py
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
# choose a value for temperature scaling: 0.00001
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/12.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/5.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/29.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/6.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/15.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/25.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/26.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/7.jpg
# /content/anomalysegmentation/Validation_Dataset/fs_static/images/8.jpg
# ...
